# %%
import requests
from bs4 import BeautifulSoup
import time

# %%
# URL에서 html가져오는 함수
def HTML가져오기(url):
   _html = ""
   resp = requests.get(url) # URL에 GET 요청을 보내서 돌아온 응답(response)
   if resp.status_code == 200: # 200이면 정상적으로 응답이 왔다는 뜻
      _html = resp.text # 거기서 텍스트 즉 html만 가져오고
   return _html # 그걸 반환함

# %%
tables = soup.find('body').find_all('table', recursive=False)
print len(tables)
print tables[1].text.strip()

# %%
#리뷰 가져오는 함수
def 리뷰_가져오기(URL):
    html = HTML가져오기(URL) # 위에서 정의된 함수
    soup = BeautifulSoup(html, 'html.parser') # beatifuleSoup 라이브러리에 html넣어서 파싱함 
    
    네이버140자평 = soup.find('div', {'class': 'score_result'}) # score_result 클래스를 가진 div 태그
    별점들 = 네이버140자평.find_all("div",{"class": "star_score"}) 
    리뷰들 = 네이버140자평.find_all("div",{"class": "score_reple"})
    따봉들 = 네이버140자평.find_all("div",{"class": "btn_area"})
#    언따봉들 = 네이버140자평.findAll("div",{"class": "btn_area"})[1]
    
    별점 = [int(별점.em.text) for 별점 in 별점들] # [number + 10 for number in [1,2,3]]의 결과는 [11, 12, 13]
    리뷰 = [리뷰.p.text.replace('BEST', '') for 리뷰 in 리뷰들]
    따봉 = [int(따봉.strong.span.text) for 따봉 in 따봉들]
#    언따봉 = [int(언따봉.strong.span.text) for 언따봉 in 언따봉들]

    결과 = list(zip(별점,리뷰,따봉)) # list(zip([1,2,3], [4,5,6]))의 결과는 [(1,4), (2,5), (3,6)]
    
    return 결과

# %%
영화코드 = '136900'
URL = 'http://movie.naver.com/movie/bi/mi/pointWriteFormList.nhn?code='+ 영화코드 +'&type=after&isActualPointWriteExecute=false&isMileageSubscriptionAlready=false&isMileageSubscriptionReject=false&page='
가져올_페이지_수 = 500

네이버리뷰 = []
for 페이지 in range(1,가져올_페이지_수+1):
    네이버리뷰 += 리뷰_가져오기(URL + str(페이지))
    time.sleep(1.3)
    
    
print(네이버리뷰)
# Out:
# [(10, '마블 3000만큼 사랑합니다  ', 7397), (10, 'Avengers Assemble!  ', 5070), (10, "I'm Ironman.  ", 4813), (10, '영화 늦게 볼 수밖에 없는사람들을 생각해서 스포 자제해주세요ㅠㅠㅠ  ', 4132), (10, '아스가디언즈 오브 갤럭시 벌써부터 기대됨 ㅋㅋㅋㅋ  ', 3742), (10, '관람객아이언맨으로 시작해서 아이언맨으로 끝난다..  ', 3663), (10, '관람객마지막 한타에서 쌌습니다  ', 2802), (10, '인피니티워가 10년을 무너뜨리는 영화라면엔드게임은 10년을 돌아보는 영화입니다  ', 2729), (10, '10점 안주는 사람들은 마블에 6에서900까지밖에 애정이 없는거 ...  ', 2526), (10, '히어로물보고 울줄 누가알겠습니까  ', 2416), (10, '내 어린시절 11년을 즐겁게 해준 어벤져스 원년 멤버들... 마블 영화 한편 한편이 저의 초중고 시절, 울고 웃었던 추억이 되었어요. 아 눈물날거같애. 그동안 즐거웠고 감사했습니다.  ', 2405), (10, '쥐가다살렸음 ㅋㅋㅋㅋ  ', 2071), (10, '토르 등장씬보다 멋있는 어벤져스 집결씬  ', 2078), (8, '가장 큰 충격은 쿠키영상이 없단거다  ', 2026), (10, '[ 토니에게 따뜻한 마음이 있었다는 증거 ]  ', 1861), (10, '헤일... 하이드라...  ', 1740), (10, '관람객고맙다.나의 20대를 채워줘서  ', 1
니다...  ', 337), (10, '관람객다음 아이언맨은 아이언맨3에나온 꼬마애구나...  ', 362), (10, '마블을 대표하는 가장 상반된 두 히어로가 맞이하는 가장 서로에 가까운 결말  ', 317), (10, '너무재미있어서 눈물이난다.  ', 301), (10, '감히 내가 평가 할 수준의 영화가 아니다... 10점도 부족하다 별점 3000만큼 준비해줘요...ㅠㅠ  ', 281), (10, '옆에 여자 입틀어막고 보더라 물론 나도 같이막고봄  ', 265), (10, '마블 팬이라면 보고 기분이묘하실듯  ', 252), (10, '관람객???? : hail... hydra...  ', 247), (10, '아이언맨1부터 본사람들은 알꺼에요 이영화는 그동안 본 모든걸 보상받을 수 있는 영화라는걸  ', 230), (10, '그로 인해 시작된 이 시작을 그가 마무리 지었다  ', 224), (10, '영화 보지도 않고서 본 척 하고 스포 하는 애들 극혐. 보지도 않았는데 왜 자꾸 본 척 스포하는거임 관종인가??;  ', 238), (10, '마지막 30분이 진짜 불태웠다....전율이....  ', 219), (10, '솔직히 극한직업이랑 이 영화랑 같은 표값인게 말이안됨ㅋㅋ  ', 216), (10, '마블의 시대에 살게 해주셔서 감사합니다  ', 206), (10, '관람객완다개좋아3000만큼  ', 202), (10, '여러분 베댓이외에는 스포가 가득할것이니 평점은 읽지맙시다  ', 204), (10, '오랜 친구를 떠나보내는기분..공허하다...좌석에서 일어나자마자 그립다  ', 191), (10, '난 아이언맨이다. 이거 한줄로 충분  ', 188), (10, '관람객엔드게임이라는 부제는 누가 붙혔는지는 몰라도 진짜 완벽하다  ', 189), (10, '내가 마블영화에 네이버평점 이런거 안남기는데하나 확실한건 내가 마블영화보고 운건 처음이다단전에서 올라오는 그런 눈물 마치 내 11년의 만난 연인과 헤어지는데 동영상으로 옛 추억을 되돌려보는 느낌이랄까 가슴이 진정이 안돼고 벅찬 이 느낌을 잊기싫다  ', 181), (10, '관람객재밌었는데 왜 개인적으론 인피니티 워가 더 재밌는것 같이 느껴질까요? 아무튼 세대교체를 위한 영화 잘 봤습니다. 다음에 나오게 될 어벤져스가 기대되네요.  ', 330), (10, '9시에 적는 애들은 뭐냐 ㅋㅋ 밤 12시에 개봉했냐  ', 201), (9, '타노스... 빌런 주제에 최후까지 이토록 순교자처럼 거룩하면 어쩌잔 거냐... 아. ㅠㅠ  ', 162), (8, '재밌는데..진짜 재밌는데 개인적으로 인피니티 워가 더 소름 돋았음..  ', 228), (10, '어벤져스에 댓글 알바가 필요할까?  ', 165), (10, '지난 11년간 MCU를 사랑해준 팬들에게 마치 선물과도 같은 영화.  손수건 꼭 준비하세요 ㅠㅠ  ', 134), (10, '영화보고 버거킹 갔습니다...  ', 133), (10, '꼭 보십시요. 마블 팬이 아니어도 표값은 합니다.  ', 138), ...

# %% [markdown]
# ## csv로 쓰기

# %%
import csv

csv파일 = open('네이버영화리뷰-어벤져스_따봉추가.csv', 'w',  newline='') # 파일이 이미 있든 없든 쓰기 전용으로 열어서
csvout = csv.DictWriter(csv파일, ['별점', '리플','따봉']) # 헤더 만들고
csvout.writeheader() 

for 리뷰 in 네이버리뷰: 
    csvout.writerow({'별점': 리뷰[0], '리플': 리뷰[1], '따봉' : 리뷰[2]}) # 데이터 한 줄씩 써넣음

csv파일.close()
